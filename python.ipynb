# %%
import pandas as pd
import mysql.connector as conn
import numpy as np
import random
import re
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)  # ver todas las columnas

# %%
actor_csv=pd.read_csv(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\actor.csv')

actor_csv_ori=actor_csv.copy()

# %%
actor_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# actor_id       200 non-null int64
# first_name     200 non-null object
# last_name      200 non-null object
# last_update    200 non-null object
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
actor_csv.drop(['last_update'], axis=1, inplace=True)

# %%
actor_csv.head()
# Out:
#    actor_id first_name     last_name
# 0         1   PENELOPE       GUINESS
# 1         2       NICK      WAHLBERG
# 2         3         ED         CHASE
# 3         4   JENNIFER         DAVIS
# 4         5     JOHNNY  LOLLOBRIGIDA

# %%
filepath = Path(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\actor_clean.csv')  
actor_csv.to_csv(filepath, index=False)

# %%
category_csv=pd.read_csv(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\category.csv')

# %%
category_csv.head(5)
# Out:
#    category_id       name          last_update
# 0            1     Action  2006-02-15 04:46:27
# 1            2  Animation  2006-02-15 04:46:27
# 2            3   Children  2006-02-15 04:46:27
# 3            4   Classics  2006-02-15 04:46:27
# 4            5     Comedy  2006-02-15 04:46:27

# %%
category_csv.drop(['last_update'], axis=1, inplace=True)
filepath = Path(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\category_clean.csv')  
category_csv.to_csv(filepath,index=False)

# %%
film_csv=pd.read_csv(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\film.csv')

# %%
film_csv.nunique()
# Out:
# film_id                 1000
# title                   1000
# description             1000
# release_year               1
# language_id                1
# original_language_id       0
# rental_duration            5
# rental_rate                3
# length                   140
# replacement_cost          21
# rating                     5
# special_features          15
# last_update                1
# dtype: int64

# %%
len(max(film_csv.rating, key=len))
#recupera la longitud mas larga de una string en un alista.
#eliminar original_language_id?

film_csv.drop(['original_language_id'], axis=1, inplace=True)

# %%
filepath = Path(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\film_clean.csv')  
film_csv.to_csv(filepath,index=False)

# %%
language_csv=pd.read_csv(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\language.csv')

# %%
language_csv
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19
# 5            6    German  2006-02-15 05:02:19

# %%
language_csv.drop(['last_update'], axis=1, inplace=True)
filepath = Path(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\language_clean.csv')  
language_csv.to_csv(filepath, index=False)

# %%
rental_csv=pd.read_csv(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\rental.csv')

# %%
rental_csv.nunique()
# Out:
# rental_id       1000
# rental_date      999
# inventory_id    1000
# customer_id      485
# return_date      997
# staff_id           2
# last_update        1
# dtype: int64

# %%
listado=[x for x in rental_csv.inventory_id if x > 1000]
len(listado)
# Out:
# 788

# %%
pd.set_option('display.max_rows', None)  # ver todas las columnas

orden=rental_csv.sort_values(by=['inventory_id'])
orden.reset_index(drop=True)
# Out:
#      rental_id          rental_date  inventory_id  customer_id  \
# 0          972  2005-05-30 20:21:07             2          411
# 1          361  2005-05-27 07:03:28             6          587
# 2          995  2005-05-31 00:06:02            17          150
# 3          465  2005-05-27 20:44:36            20          261
# 4          552  2005-05-28 07:53:38            23          106
# 5          317  2005-05-26 23:23:56            26          391
# 6          259  2005-05-26 15:32:46            30          482
# 7          120  2005-05-25 19:37:47            37          365
# 8          785  2005-05-29 15:08:41            39           72
# 9          563  2005-05-28 09:10:49            53          324
# 10         633  2005-05-28 17:37:59            58          360
# 11         827  2005-05-29 21:58:43            62          573
# 12         983  2005-05-30 22:15:51            63          115
# 13         505  2005-05-28 02:06:37            71          111
# ...

# %%
orden=rental_csv.sort_values(by=['rental_id'])
#orden.reset_index(drop=True)

# %%
listita=orden['inventory_id'].unique()
listita.sort()

# %%
rental_csv.drop(['last_update'], axis=1, inplace=True)

# %%
filepath = Path(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\rental_clean.csv')  
rental_csv.to_csv(filepath, index=False)

# %%
film_csv.drop(['last_update'], axis=1, inplace=True)

# %%
filepath = Path(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\film_clean.csv')  
film_csv.to_csv(filepath, index=False)

# %%
inventory_csv=pd.read_csv(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\inventory.csv')
#inventory_csv.drop(['last_update'], axis=1, inplace=True)

# %%
contador=1001
new_row = []
for x in range(1001, 4581):    
    pelicula=random.randint(1,223)
    inventario = contador
    tienda = random.randint(1,2)
    if contador in listita and contador > 1001:    
        dictio={'inventory_id':inventario, 'film_id':pelicula, 'store_id':tienda}
        new_row.append(dictio)
        
    contador +=1

# %%
inventory2=inventory_csv.append(new_row, ignore_index=True)

# %%
inventory2.tail()
# Out:
#       inventory_id  film_id  store_id last_update
# 1782          4556      160         2         NaN
# 1783          4558        5         2         NaN
# 1784          4568      165         2         NaN
# 1785          4573      202         1         NaN
# 1786          4579      157         2         NaN

# %%
inventory2.drop(['last_update'], axis=1, inplace=True)
filepath = Path(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\inventory_clean.csv')  
inventory2.to_csv(filepath, index=False)

# %%
hdd_csv=pd.read_csv(r'C:\Users\USER\Desktop\Proyectos\sql-data-base-building\data\old_HDD.csv')

# %%
hdd_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
# first_name      1000 non-null object
# last_name       1000 non-null object
# title           1000 non-null object
# release_year    1000 non-null int64
# category_id     1000 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB

# %%
# %pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conexion=conn.connect(host='localhost', user='root', passwd='1234') # conexion al servidor

cursor=conexion.cursor()
cursor.execute

#data.to_sql(name='w3_project', con=cursor, if_exists='replace', index=False)
# Out:
# <bound method CMySQLCursor.execute of <mysql.connector.cursor_cext.CMySQLCursor object at 0x000002393FD989C8>>
